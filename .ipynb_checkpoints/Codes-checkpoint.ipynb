# %%
import pandas as pd

# %%
data = pd.read_csv("olist_public_dataset_v2.csv")
data = data.set_index('order_id')
data.head()
# Out:
#                                  order_status  order_products_value  \
# order_id
# b95df3cef5297e79ef709ba256518f6f    delivered                349.90
# 59af46052a799e80e2f0c665c587731d    delivered                 15.00
# a3e6136894621db402a772c6bc72a12a    delivered                238.90
# b675ea5a618922f6e679e30531b8957b    delivered                 29.99
# 195a8be6794c487fe6cfbb97b7c61902    delivered                295.99
#
#                                   order_freight_value  order_items_qty  \
# order_id
# b95df3cef5297e79ef709ba256518f6f                13.84                1
# 59af46052a799e80e2f0c665c587731d                15.10                1
# a3e6136894621db402a772c6bc72a12a                18.00                1
# b675ea5a618922f6e679e30531b8957b                18.23                1
# 195a8be6794c487fe6cfbb97b7c61902                47.65                1
#
#                                   order_sellers_qty  \
# order_id
# ...

# %%
len(data)
# Out:
# 100000

# %%
data = data.drop_duplicates()

# %%
len(data)
# Out:
# 100000
