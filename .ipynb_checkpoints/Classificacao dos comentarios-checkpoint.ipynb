# %%
import pandas as pd
data = pd.read_csv("olist_public_dataset_v2.csv")
data.set_index('order_id')
data.head()
# Out:
#                            order_id order_status  order_products_value  \
# 0  b95df3cef5297e79ef709ba256518f6f    delivered                349.90
# 1  59af46052a799e80e2f0c665c587731d    delivered                 15.00
# 2  a3e6136894621db402a772c6bc72a12a    delivered                238.90
# 3  b675ea5a618922f6e679e30531b8957b    delivered                 29.99
# 4  195a8be6794c487fe6cfbb97b7c61902    delivered                295.99
#
#    order_freight_value  order_items_qty  order_sellers_qty  \
# 0                13.84                1                  1
# 1                15.10                1                  1
# 2                18.00                1                  1
# 3                18.23                1                  1
# 4                47.65                1                  1
#
#      order_purchase_timestamp            order_aproved_at  \
# 0  2017-01-31 17:19:01.000000  2017-02-01 02:41:21.549551
# 1  2017-09-09 19:52:54.000000  2017-09-10 20:03:31.535281
# ...

# %%
lista_classificacao= []
for i in data.review_score:
    
    if i == 5 or i == 4:
        classificacao = 1
        
    if i ==3:
        classificacao = 0
        
    if i == 2 or i == 1:
        classificacao = -1
        
    lista_classificacao.append(classificacao)
    
data["Classificacao"]=lista_classificacao
data['delivery_date'] = pd.to_datetime(data['order_delivered_customer_date'])
data['aproved_date'] = pd.to_datetime(data['order_aproved_at'])
data['delta time'] = data['delivery_date'] - data['aproved_date']
data['delta_days'] = (data['delta time'].dt.days)

# %%
states_numbers = []
for state in data['costumer_state']:
    if state == 'SP':
        states_numbers.append(1)
    if state == 'RJ':
        states_numbers.append(2)
    if state == 'MG':
        states_numbers.append(3)
    if state == 'RS':
        states_numbers.append(4)
    if state == 'PR':
        states_numbers.append(5)
    if state == 'SC':
        states_numbers.append(6)
    if state == 'BA':
        states_numbers.append(7)
    if state == 'DF':
        states_numbers.append(8)
    if state == 'ES':
        states_numbers.append(9)
    if state == 'GO':
        states_numbers.append(10)
    if state == 'PE':
        states_numbers.append(11)
    if state == 'CE':
        states_numbers.append(12)
    if state == 'PA':
        states_numbers.append(13)
    if state == 'MT':
        states_numbers.append(14)
    if state == 'MA':
        states_numbers.append(15)
    if state == 'MS':
        states_numbers.append(16)
    if state == 'PB':
        states_numbers.append(17)
    if state == 'RN':
        states_numbers.append(18)
    if state == 'PI':
        states_numbers.append(19)
    if state == 'AL':
        states_numbers.append(20)
    if state == 'SE':
        states_numbers.append(21)
    if state == 'RO':
        states_numbers.append(22)
    if state == 'TO':
        states_numbers.append(23)
    if state == 'AM':
        states_numbers.append(24)
    if state == 'AC':
        states_numbers.append(25)
    if state == 'AP':
        states_numbers.append(26)
    if state == 'RR':
        states_numbers.append(27)
        
data["states_numbers"] = states_numbers
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2524             try:
# -> 2525                 return self._engine.get_loc(key)
#    2526             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'costumer_state'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-71-a7059aa95758> in <module>()
#       1 states_numbers = []
# ...

# %%
data['customer_state'].value_counts()
# Out:
# SP    41020
# RJ    13486
# MG    11977
# RS     5586
# PR     5027
# SC     3747
# BA     3459
# DF     2051
# ES     2040
# GO     2011
# PE     1638
# CE     1327
# PA     1023
# MT      922
# MA      763
# MS      725
# PB      542
# RN      519
# PI      454
# AL      440
# SE      339
# RO      287
# TO      261
# AM      156
# AC       86
# AP       68
# RR       46
# Name: customer_state, dtype: int64

# %%
from sklearn.model_selection import train_test_split

df = data[['order_products_value', 'order_freight_value', 'product_description_lenght', 'product_photos_qty', 'review_score', 'review_comment_message', 'delta_days', 'Classificacao', 'customer_state']]
df = df.dropna()

print(len(df))
dados_treinamento, dados_teste = train_test_split(df, test_size=0.4)
print(len(dados_treinamento))
print(len(dados_teste))
# Out:
# 40892
# 24535
# 16357

# %%
y_train= dados_treinamento.Classificacao
x_train= dados_treinamento.review_comment_message
x_test= dados_teste.review_comment_message
y_test= dados_teste.Classificacao

# %%
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.metrics import accuracy_score
from sklearn.naive_bayes import MultinomialNB
from sklearn.pipeline import Pipeline

# Cria modelo.
model = Pipeline([
    ("vectorizer", CountVectorizer()),
    ("classifier", MultinomialNB())
])

# Treina modelo.
model.fit(x_train, y_train)
# Out:
# Pipeline(memory=None,
#      steps=[('vectorizer', CountVectorizer(analyzer='word', binary=False, decode_error='strict',
#         dtype=<class 'numpy.int64'>, encoding='utf-8', input='content',
#         lowercase=True, max_df=1.0, max_features=None, min_df=1,
#         ngram_range=(1, 1), preprocessor=None, stop_words=None,
#         strip_accents=None, token_pattern='(?u)\\b\\w\\w+\\b',
#         tokenizer=None, vocabulary=None)), ('classifier', MultinomialNB(alpha=1.0, class_prior=None, fit_prior=True))])

# %%
# Testa modelo.
pos_prob = []
neg_prob = []
neu_prob = []
probs = model.predict_proba(x_train)
for e in probs:
    neg_prob.append(e[0])
    neu_prob.append(e[1])
    pos_prob.append(e[2])
dados_treinamento['pos_prob'] = pos_prob
dados_treinamento['neg_prob'] = neg_prob
dados_treinamento['neu_prob'] = neu_prob
dados_treinamento.head()


pos_prob = []
neg_prob = []
neu_prob = []
probs = model.predict_proba(x_test)
for e in probs:
    neg_prob.append(e[0])
    neu_prob.append(e[1])
    pos_prob.append(e[2])
dados_teste['pos_prob'] = pos_prob
dados_teste['neg_prob'] = neg_prob
dados_teste['neu_prob'] = neu_prob
# Out:
# C:\Users\rafae\Anaconda3\lib\site-packages\ipykernel_launcher.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   # Remove the CWD from sys.path while we load stuff.
# C:\Users\rafae\Anaconda3\lib\site-packages\ipykernel_launcher.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   # This is added back by InteractiveShellApp.init_path()
# C:\Users\rafae\Anaconda3\lib\site-packages\ipykernel_launcher.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# ...

# %%
dados_treinamento.to_csv('train_data.csv')
dados_teste.to_csv('test_data.csv')

# %%
data.columns
# Out:
# Index(['order_id', 'order_status', 'order_products_value',
#        'order_freight_value', 'order_items_qty', 'order_sellers_qty',
#        'order_purchase_timestamp', 'order_aproved_at',
#        'order_estimated_delivery_date', 'order_delivered_customer_date',
#        'customer_id', 'customer_city', 'customer_state',
#        'customer_zip_code_prefix', 'product_category_name',
#        'product_name_lenght', 'product_description_lenght',
#        'product_photos_qty', 'product_id', 'review_id', 'review_score',
#        'review_comment_title', 'review_comment_message',
#        'review_creation_date', 'review_answer_timestamp', 'Classificacao',
#        'delivery_date', 'aproved_date', 'delta time', 'delta_days'],
#       dtype='object')
