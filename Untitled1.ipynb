# %%
import pandas as pd

# %%
aa = pd.read_csv("olist_public_dataset_v2.csv")
aa.set_index('order_id')
# Out:
#                                  order_status  order_products_value  \
# order_id
# b95df3cef5297e79ef709ba256518f6f    delivered                349.90
# 59af46052a799e80e2f0c665c587731d    delivered                 15.00
# a3e6136894621db402a772c6bc72a12a    delivered                238.90
# b675ea5a618922f6e679e30531b8957b    delivered                 29.99
# 195a8be6794c487fe6cfbb97b7c61902    delivered                295.99
# 80dbbd6f2282898dbf912a2ec668175f    delivered                160.00
# 0f374228bdae432c9bdda69f21ccd261    delivered                 25.00
# d02366be68b26b954269321e475a79fe    delivered                 43.30
# d42c3af33e0f04b3d5f012b6559e70c9    delivered                 89.90
# 92e9390c69bcb745fe059efdf93cac2a    delivered                 40.00
# 11edf2e8e2e689ab25e609f6a45b5b7a    delivered                119.90
# 8fe9a9aa8481e4ca00f5b2e2c84bada8    delivered                 59.90
# 9a641b73a061b55f9ff0c8cf68b84f34    delivered                187.00
# ...

# %%
aa.columns
# Out:
# Index(['order_id', 'order_status', 'order_products_value',
#        'order_freight_value', 'order_items_qty', 'order_sellers_qty',
#        'order_purchase_timestamp', 'order_aproved_at',
#        'order_estimated_delivery_date', 'order_delivered_customer_date',
#        'customer_id', 'customer_city', 'customer_state',
#        'customer_zip_code_prefix', 'product_category_name',
#        'product_name_lenght', 'product_description_lenght',
#        'product_photos_qty', 'product_id', 'review_id', 'review_score',
#        'review_comment_title', 'review_comment_message',
#        'review_creation_date', 'review_answer_timestamp'],
#       dtype='object')

# %%
bb = aa[['review_comment_message']]
print(len(bb))
bb = bb.dropna()
print(len(bb))
# Out:
# 100000
# 42489

# %%
bb = aa[['order_aproved_at']]
print(len(bb))
bb = bb.dropna()
print(len(bb))
# Out:
# 100000
# 99982

# %%
bb = aa[['order_delivered_customer_date']]
print(len(bb))
bb = bb.dropna()
print(len(bb))
# Out:
# 100000
# 97595

# %%
bb = aa[['product_description_lenght']]
print(len(bb))
bb = bb.dropna()
print(len(bb))
# Out:
# 100000
# 100000

# %%
bb = aa[['product_photos_qty']]
print(len(bb))
bb = bb.dropna()
print(len(bb))
# Out:
# 100000
# 100000

# %%
bb = aa[['review_score']]
print(len(bb))
bb = bb.dropna()
print(len(bb))
# Out:
# 100000
# 100000

# %%
bb = aa[['review_comment_message']]
print(len(bb))
bb = bb.dropna()
print(len(bb))
# Out:
# 100000
# 42489

# %%
bb = aa[['order_products_value', 'order_freight_value', 'product_description_lenght', 'product_photos_qty']]
bb = bb.dropna()
len(bb)
# Out:
# 100000
